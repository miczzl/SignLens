# %% [markdown]
# # 1. Import and Install Dependencies

# %%
#!pip install tensorflow opencv-python mediapipe sklearn matplotlib

# %%
import os
import cv2
import mediapipe as mp
import numpy as np
from matplotlib import pyplot as plt
import time

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    # Transfer image
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    # Make prediction
    results = model.process(image)
    return results

# %%
def draw_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION)
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
    # Draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(
        image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
        mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
        mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
    )
    # Draw pose connections
    mp_drawing.draw_landmarks(
        image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
        mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
        mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
    )
    # Draw left hand connections
    mp_drawing.draw_landmarks(
        image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
        mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
        mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
    ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(
        image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
        mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
        mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
    )

# %% [markdown]
# ### Capture Landmarks with VideoCam

# %%
def capture_landmarks():
    cap = cv2.VideoCapture(0)
    # Set mediapipe model 
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

        # Read feed
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            # Make detections
            results = mediapipe_detection(frame, holistic)
            # Draw landmarks
            draw_styled_landmarks(frame, results)
            # Show to screen
            cv2.imshow('OpenCV Feed', frame)

            # Break gracefully
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                break

        cap.release()
        cv2.destroyAllWindows()

# %%
# capture_landmarks()

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
def extract_keypoints(results):
    # Extract keypoints if landmarks captured, else fill with zeros
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# # 4. Collect Keypoints Values from Videos

# %%
def slice_video(path):
    cap = cv2.VideoCapture(path)
    
    count = 0
    action = {}
    # Set mediapipe model
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

        # Read feed
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                print("No frame received...")
                break

            # Make detections
            results = mediapipe_detection(frame, holistic)
            # Draw landmarks
            draw_styled_landmarks(frame, results)

            # Draw frame counter
            count += 1
            cv2.putText(frame, f'Frame {count}', (10,30), 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA) 

            # Show to screen
            cv2.imshow('OpenCV Feed', frame)

            # Extract frame
            img_path = os.path.join('MP_Video', video_name, f'{count}.jpg')
            cv2.imwrite(img_path, frame)

            # Extract keypoints
            keypoints = extract_keypoints(results)
            npy_path = os.path.join('MP_Video', video_name, str(count))
            np.save(npy_path, keypoints)

            # Break & pause
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                break
            if key == ord(' '):
                i = len(action) + 1
                action[i] = count

        print(f"{video_name} = {action}")
        cap.release()
        cv2.destroyAllWindows()

# %%
def check_collection(filename, start_frame, length=29):
    end_frame = start_frame + length
    i = start_frame
    while True:

        # Reply logic
        i = start_frame if i == end_frame else i + 1

        # Show image
        img_path = os.path.join('MP_Video', filename, f"{i}.jpg")
        frame = cv2.imread(img_path)
        cv2.imshow(f'Frame {start_frame} to {end_frame}', frame)

        # Break gracefully
        key = cv2.waitKey(10) & 0xFF
        if key == ord('q'):
            break

    cv2.destroyAllWindows()

# %%
def compile_data(dic, file_name, action_name):
    data_num = int(file_name.split('_')[-1]) * 10 - 10
    for key, value in dic.items():
        if type(value) == tuple:
            value = value[0]
        print(key + data_num, value)
        seq = []
        for i in range(value, value+30):
            frame = np.load(os.path.join('MP_Video', file_name, "{}.npy".format(i)))
            seq.append(frame)
        seq_npy = np.array(seq)
        np.save(os.path.join('SL_Data', action_name, "{}.npy".format(key + data_num)), seq_npy)

# %% [markdown]
# # 5. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
actions = np.array(['i',
                    'my',
                    'children',
                    'have',
                    'dont_have',
                    'only_have',
                    'is',
                    'good',
                    'need',
                    'deal', 
                    'forget',
                    'bring',
                    'replace',
                    'help',
                    'single',
                    'below',
                    'stamp',
                    'card',
                    'account'])

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'end': 0, 'meeting': 1, 'thank': 2}

# %%
sequences, labels = None, []
for action in actions:
    for i in range(40):
        data = np.load(os.path.join('SL_Data', action, i, "{}.npy".format(i+1)))
        if sequences is None:
            sequences = data
        else:
            sequences = np.append(sequences, data, axis=0)
        labels.append(label_map[action])

# %%
X = sequences.reshape(-1,30,1662)
X.shape
# Out:
# (120, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
y_test.shape
# Out:
# (12, 3)

# %% [markdown]
# # 6. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
# Layer
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(30,1662)))
model.add(Dense(64, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
# optimizer, loss, accuracy
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
# epochs, callback
model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 2s 56ms/step - loss: 1.5526 - categorical_accuracy: 0.2963
# Epoch 2/1000
# 4/4 [==============================] - 0s 83ms/step - loss: 2.2543 - categorical_accuracy: 0.3704
# Epoch 3/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 1.5027 - categorical_accuracy: 0.3333
# Epoch 4/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 1.5742 - categorical_accuracy: 0.3704
# Epoch 5/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 1.2123 - categorical_accuracy: 0.3426
# Epoch 6/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 1.1473 - categorical_accuracy: 0.3148
# Epoch 7/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.2014 - categorical_accuracy: 0.2963
# Epoch 8/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 1.1112 - categorical_accuracy: 0.3704
# Epoch 9/1000
# 4/4 [==============================] - 0s 74ms/step - loss: 1.1621 - categorical_accuracy: 0.2222
# Epoch 10/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 1.0897 - categorical_accuracy: 0.4630
# Epoch 11/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 1.1124 - categorical_accuracy: 0.4074
# Epoch 12/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 1.1067 - categorical_accuracy: 0.3611
# Epoch 13/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 1.0812 - categorical_accuracy: 0.3519
# Epoch 14/1000
# 4/4 [==============================] - 0s 69ms/step - loss: 1.0903 - categorical_accuracy: 0.4167
# Epoch 15/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 1.0445 - categorical_accuracy: 0.3889
# Epoch 16/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 1.0639 - categorical_accuracy: 0.3241
# Epoch 17/1000
# 4/4 [==============================] - 0s 75ms/step - loss: 1.0266 - categorical_accuracy: 0.4815
# Epoch 18/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 1.0306 - categorical_accuracy: 0.4167
# Epoch 19/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 1.0232 - categorical_accuracy: 0.4722
# Epoch 20/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 1.0169 - categorical_accuracy: 0.4815
# Epoch 21/1000
# 4/4 [==============================] - 0s 76ms/step - loss: 1.0088 - categorical_accuracy: 0.4074
# Epoch 22/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 1.0392 - categorical_accuracy: 0.4630
# Epoch 23/1000
# 4/4 [==============================] - 0s 69ms/step - loss: 1.0621 - categorical_accuracy: 0.3796
# Epoch 24/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 1.0022 - categorical_accuracy: 0.5185
# Epoch 25/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 1.0602 - categorical_accuracy: 0.4167
# Epoch 26/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 1.0344 - categorical_accuracy: 0.3796
# Epoch 27/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 1.0385 - categorical_accuracy: 0.4167
# Epoch 28/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 1.0448 - categorical_accuracy: 0.5000
# Epoch 29/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 1.0076 - categorical_accuracy: 0.5185
# Epoch 30/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 1.0108 - categorical_accuracy: 0.5185
# Epoch 31/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.9854 - categorical_accuracy: 0.4352
# Epoch 32/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.9843 - categorical_accuracy: 0.5185
# Epoch 33/1000
# 4/4 [==============================] - 0s 72ms/step - loss: 0.9906 - categorical_accuracy: 0.4352
# Epoch 34/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.9645 - categorical_accuracy: 0.4907
# Epoch 35/1000
# 4/4 [==============================] - 0s 70ms/step - loss: 0.9788 - categorical_accuracy: 0.4815
# Epoch 36/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.9805 - categorical_accuracy: 0.4630
# Epoch 37/1000
# 4/4 [==============================] - 0s 80ms/step - loss: 1.0038 - categorical_accuracy: 0.4722
# Epoch 38/1000
# 4/4 [==============================] - 0s 82ms/step - loss: 0.9366 - categorical_accuracy: 0.5463
# Epoch 39/1000
# 4/4 [==============================] - 0s 70ms/step - loss: 0.9873 - categorical_accuracy: 0.6019
# Epoch 40/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.9725 - categorical_accuracy: 0.4907
# Epoch 41/1000
# 4/4 [==============================] - 0s 82ms/step - loss: 1.0821 - categorical_accuracy: 0.4352
# Epoch 42/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.2496 - categorical_accuracy: 0.2870
# Epoch 43/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 1.1315 - categorical_accuracy: 0.4444
# Epoch 44/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 1.0332 - categorical_accuracy: 0.5463
# Epoch 45/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.9761 - categorical_accuracy: 0.5370
# Epoch 46/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.0042 - categorical_accuracy: 0.5556
# Epoch 47/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.9350 - categorical_accuracy: 0.5185
# Epoch 48/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.9592 - categorical_accuracy: 0.5093
# Epoch 49/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.9464 - categorical_accuracy: 0.4907
# Epoch 50/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.9174 - categorical_accuracy: 0.5278
# Epoch 51/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.9306 - categorical_accuracy: 0.6019
# Epoch 52/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.9008 - categorical_accuracy: 0.5370
# Epoch 53/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.8767 - categorical_accuracy: 0.5648
# Epoch 54/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.8915 - categorical_accuracy: 0.5093
# Epoch 55/1000
# 4/4 [==============================] - 0s 84ms/step - loss: 0.9380 - categorical_accuracy: 0.5370
# Epoch 56/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.9301 - categorical_accuracy: 0.4815
# Epoch 57/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.9555 - categorical_accuracy: 0.4722
# Epoch 58/1000
# 4/4 [==============================] - 0s 88ms/step - loss: 0.8441 - categorical_accuracy: 0.5278
# Epoch 59/1000
# 4/4 [==============================] - 0s 82ms/step - loss: 0.8489 - categorical_accuracy: 0.6204
# Epoch 60/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 0.8179 - categorical_accuracy: 0.6111
# Epoch 61/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.9165 - categorical_accuracy: 0.5000
# Epoch 62/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 1.0656 - categorical_accuracy: 0.4352
# Epoch 63/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.9691 - categorical_accuracy: 0.4815
# Epoch 64/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.9298 - categorical_accuracy: 0.5000
# Epoch 65/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.9216 - categorical_accuracy: 0.4630
# Epoch 66/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 0.8693 - categorical_accuracy: 0.4815
# Epoch 67/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.8741 - categorical_accuracy: 0.5370
# Epoch 68/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.8313 - categorical_accuracy: 0.6111
# Epoch 69/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.8582 - categorical_accuracy: 0.5185
# Epoch 70/1000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.7886 - categorical_accuracy: 0.6204
# Epoch 71/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.7428 - categorical_accuracy: 0.5833
# Epoch 72/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.7210 - categorical_accuracy: 0.6574
# Epoch 73/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.6821 - categorical_accuracy: 0.6111
# Epoch 74/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 0.7855 - categorical_accuracy: 0.6667
# Epoch 75/1000
# 4/4 [==============================] - 0s 72ms/step - loss: 0.9809 - categorical_accuracy: 0.5741
# Epoch 76/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.8062 - categorical_accuracy: 0.5556
# Epoch 77/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.8391 - categorical_accuracy: 0.5463
# Epoch 78/1000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.7932 - categorical_accuracy: 0.6111
# Epoch 79/1000
# 4/4 [==============================] - 0s 82ms/step - loss: 0.7363 - categorical_accuracy: 0.6389
# Epoch 80/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 0.7346 - categorical_accuracy: 0.6481
# Epoch 81/1000
# 4/4 [==============================] - 0s 76ms/step - loss: 0.7336 - categorical_accuracy: 0.5833
# Epoch 82/1000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.7523 - categorical_accuracy: 0.6296
# Epoch 83/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.6625 - categorical_accuracy: 0.7407
# Epoch 84/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.6107 - categorical_accuracy: 0.7500
# Epoch 85/1000
# 4/4 [==============================] - 0s 83ms/step - loss: 0.6100 - categorical_accuracy: 0.7315
# Epoch 86/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.6960 - categorical_accuracy: 0.6574
# Epoch 87/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.8312 - categorical_accuracy: 0.5648
# Epoch 88/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.0319 - categorical_accuracy: 0.5185
# Epoch 89/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.8495 - categorical_accuracy: 0.6759
# Epoch 90/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.7794 - categorical_accuracy: 0.6759
# Epoch 91/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.7647 - categorical_accuracy: 0.6481
# Epoch 92/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.7491 - categorical_accuracy: 0.5463
# Epoch 93/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.6947 - categorical_accuracy: 0.7870
# Epoch 94/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.6397 - categorical_accuracy: 0.7870
# Epoch 95/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.5847 - categorical_accuracy: 0.8148
# Epoch 96/1000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.5398 - categorical_accuracy: 0.7407
# Epoch 97/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.4956 - categorical_accuracy: 0.7870
# Epoch 98/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.5594 - categorical_accuracy: 0.7315
# Epoch 99/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 0.6984 - categorical_accuracy: 0.6019
# Epoch 100/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.7883 - categorical_accuracy: 0.6852
# Epoch 101/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.5891 - categorical_accuracy: 0.7407
# Epoch 102/1000
# 4/4 [==============================] - 0s 69ms/step - loss: 0.6466 - categorical_accuracy: 0.6852
# Epoch 103/1000
# 4/4 [==============================] - 0s 77ms/step - loss: 0.5859 - categorical_accuracy: 0.7407
# Epoch 104/1000
# 4/4 [==============================] - 0s 78ms/step - loss: 0.5109 - categorical_accuracy: 0.8148
# Epoch 105/1000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.4768 - categorical_accuracy: 0.8426
# Epoch 106/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.4800 - categorical_accuracy: 0.8056
# Epoch 107/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.9504 - categorical_accuracy: 0.5093
# Epoch 108/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.8324 - categorical_accuracy: 0.5741
# Epoch 109/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.8182 - categorical_accuracy: 0.5556
# Epoch 110/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.8043 - categorical_accuracy: 0.5370
# Epoch 111/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.7039 - categorical_accuracy: 0.6667
# Epoch 112/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.6393 - categorical_accuracy: 0.7130
# Epoch 113/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.6318 - categorical_accuracy: 0.7315
# Epoch 114/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.5921 - categorical_accuracy: 0.8056
# Epoch 115/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5706 - categorical_accuracy: 0.7870
# Epoch 116/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4995 - categorical_accuracy: 0.8241
# Epoch 117/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5165 - categorical_accuracy: 0.8426
# Epoch 118/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4884 - categorical_accuracy: 0.8241
# Epoch 119/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4537 - categorical_accuracy: 0.8426
# Epoch 120/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 0.4082 - categorical_accuracy: 0.8519
# Epoch 121/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.3987 - categorical_accuracy: 0.8241
# Epoch 122/1000
# 4/4 [==============================] - 0s 73ms/step - loss: 0.4131 - categorical_accuracy: 0.8148
# Epoch 123/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.4188 - categorical_accuracy: 0.7778
# Epoch 124/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6020 - categorical_accuracy: 0.7407
# Epoch 125/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.7182 - categorical_accuracy: 0.6852
# Epoch 126/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.3942 - categorical_accuracy: 0.8426
# Epoch 127/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.4535 - categorical_accuracy: 0.7778
# Epoch 128/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.4892 - categorical_accuracy: 0.7778
# Epoch 129/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.4722 - categorical_accuracy: 0.7593
# Epoch 130/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 0.4345 - categorical_accuracy: 0.7778
# Epoch 131/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.3627 - categorical_accuracy: 0.8796
# Epoch 132/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.4198 - categorical_accuracy: 0.8056
# Epoch 133/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.7141 - categorical_accuracy: 0.7037
# Epoch 134/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.6420 - categorical_accuracy: 0.7315
# Epoch 135/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.5757 - categorical_accuracy: 0.6944
# Epoch 136/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.5143 - categorical_accuracy: 0.7685
# Epoch 137/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.5474 - categorical_accuracy: 0.7222
# Epoch 138/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.4392 - categorical_accuracy: 0.8148
# Epoch 139/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.3988 - categorical_accuracy: 0.8796
# Epoch 140/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.3753 - categorical_accuracy: 0.8704
# Epoch 141/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.3550 - categorical_accuracy: 0.8426
# Epoch 142/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.3406 - categorical_accuracy: 0.8704
# Epoch 143/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.3842 - categorical_accuracy: 0.8148
# Epoch 144/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.4726 - categorical_accuracy: 0.7500
# Epoch 145/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3026 - categorical_accuracy: 0.8611
# Epoch 146/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.3552 - categorical_accuracy: 0.8148
# Epoch 147/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.5904 - categorical_accuracy: 0.7315
# Epoch 148/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.8733 - categorical_accuracy: 0.6667
# Epoch 149/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.6289 - categorical_accuracy: 0.6667
# Epoch 150/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.6057 - categorical_accuracy: 0.7500
# Epoch 151/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.6269 - categorical_accuracy: 0.6852
# Epoch 152/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.6235 - categorical_accuracy: 0.6481
# Epoch 153/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.4994 - categorical_accuracy: 0.8148
# Epoch 154/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.5427 - categorical_accuracy: 0.7222
# Epoch 155/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.4872 - categorical_accuracy: 0.7685
# Epoch 156/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.3976 - categorical_accuracy: 0.8519
# Epoch 157/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.4206 - categorical_accuracy: 0.8241
# Epoch 158/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.4013 - categorical_accuracy: 0.8333
# Epoch 159/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.5155 - categorical_accuracy: 0.7407
# Epoch 160/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.5517 - categorical_accuracy: 0.7130
# Epoch 161/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.5488 - categorical_accuracy: 0.7407
# Epoch 162/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.3817 - categorical_accuracy: 0.8519
# Epoch 163/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 0.3528 - categorical_accuracy: 0.8704
# Epoch 164/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.3353 - categorical_accuracy: 0.8611
# Epoch 165/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3591 - categorical_accuracy: 0.8241
# Epoch 166/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 0.3512 - categorical_accuracy: 0.8333
# Epoch 167/1000
# 4/4 [==============================] - 0s 96ms/step - loss: 0.3714 - categorical_accuracy: 0.7870
# Epoch 168/1000
# 4/4 [==============================] - 0s 76ms/step - loss: 0.3423 - categorical_accuracy: 0.8333
# Epoch 169/1000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.3029 - categorical_accuracy: 0.8796
# Epoch 170/1000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.4827 - categorical_accuracy: 0.7778
# Epoch 171/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2951 - categorical_accuracy: 0.8796
# Epoch 172/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.2974 - categorical_accuracy: 0.8704
# Epoch 173/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.4272 - categorical_accuracy: 0.7870
# Epoch 174/1000
# 4/4 [==============================] - 0s 91ms/step - loss: 0.4988 - categorical_accuracy: 0.7685
# Epoch 175/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 0.3053 - categorical_accuracy: 0.8519
# Epoch 176/1000
# 4/4 [==============================] - 0s 73ms/step - loss: 0.3227 - categorical_accuracy: 0.8704
# Epoch 177/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.3370 - categorical_accuracy: 0.8519
# Epoch 178/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.6014 - categorical_accuracy: 0.7593
# Epoch 179/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.8855 - categorical_accuracy: 0.6296
# Epoch 180/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.8368 - categorical_accuracy: 0.6019
# Epoch 181/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.7641 - categorical_accuracy: 0.5833
# Epoch 182/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.8920 - categorical_accuracy: 0.5556
# Epoch 183/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6891 - categorical_accuracy: 0.7037
# Epoch 184/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.7461 - categorical_accuracy: 0.6296
# Epoch 185/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.6205 - categorical_accuracy: 0.6667
# Epoch 186/1000
# 4/4 [==============================] - 0s 74ms/step - loss: 0.5834 - categorical_accuracy: 0.7407
# Epoch 187/1000
# 4/4 [==============================] - 0s 77ms/step - loss: 0.5570 - categorical_accuracy: 0.7407
# Epoch 188/1000
# 4/4 [==============================] - 0s 70ms/step - loss: 0.4578 - categorical_accuracy: 0.8333
# Epoch 189/1000
# 4/4 [==============================] - 0s 72ms/step - loss: 0.4126 - categorical_accuracy: 0.8704
# Epoch 190/1000
# 4/4 [==============================] - 0s 77ms/step - loss: 0.3841 - categorical_accuracy: 0.8426
# Epoch 191/1000
# 4/4 [==============================] - 0s 81ms/step - loss: 0.3631 - categorical_accuracy: 0.8704
# Epoch 192/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 0.3296 - categorical_accuracy: 0.8796
# Epoch 193/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.2685 - categorical_accuracy: 0.9074
# Epoch 194/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.2546 - categorical_accuracy: 0.9074
# Epoch 195/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.2578 - categorical_accuracy: 0.8981
# Epoch 196/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2291 - categorical_accuracy: 0.9259
# Epoch 197/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2223 - categorical_accuracy: 0.9167
# Epoch 198/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2023 - categorical_accuracy: 0.9352
# Epoch 199/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2073 - categorical_accuracy: 0.9074
# Epoch 200/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1847 - categorical_accuracy: 0.9444
# Epoch 201/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2814 - categorical_accuracy: 0.8426
# Epoch 202/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5881 - categorical_accuracy: 0.7963
# Epoch 203/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.6270 - categorical_accuracy: 0.7870
# Epoch 204/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.6779 - categorical_accuracy: 0.7593
# Epoch 205/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.8563 - categorical_accuracy: 0.7037
# Epoch 206/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.5541 - categorical_accuracy: 0.7315
# Epoch 207/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.5302 - categorical_accuracy: 0.8148
# Epoch 208/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4254 - categorical_accuracy: 0.8056
# Epoch 209/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.4231 - categorical_accuracy: 0.8148
# Epoch 210/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.6182 - categorical_accuracy: 0.6944
# Epoch 211/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.6814 - categorical_accuracy: 0.7222
# Epoch 212/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.6099 - categorical_accuracy: 0.6759
# Epoch 213/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.6789 - categorical_accuracy: 0.7130
# Epoch 214/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.0987 - categorical_accuracy: 0.5926
# Epoch 215/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.8562 - categorical_accuracy: 0.5185
# Epoch 216/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.8130 - categorical_accuracy: 0.6204
# Epoch 217/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.6482 - categorical_accuracy: 0.6759
# Epoch 218/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5834 - categorical_accuracy: 0.6944
# Epoch 219/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.5321 - categorical_accuracy: 0.7500
# Epoch 220/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.4674 - categorical_accuracy: 0.8426
# Epoch 221/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4442 - categorical_accuracy: 0.8241
# Epoch 222/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4316 - categorical_accuracy: 0.8333
# Epoch 223/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4187 - categorical_accuracy: 0.8333
# Epoch 224/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3971 - categorical_accuracy: 0.8426
# Epoch 225/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3946 - categorical_accuracy: 0.8333
# Epoch 226/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3602 - categorical_accuracy: 0.8519
# Epoch 227/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3957 - categorical_accuracy: 0.7778
# Epoch 228/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4124 - categorical_accuracy: 0.7963
# Epoch 229/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4041 - categorical_accuracy: 0.7870
# Epoch 230/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3373 - categorical_accuracy: 0.8704
# Epoch 231/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3237 - categorical_accuracy: 0.8796
# Epoch 232/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3282 - categorical_accuracy: 0.8611
# Epoch 233/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3231 - categorical_accuracy: 0.8611
# Epoch 234/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3220 - categorical_accuracy: 0.8426
# Epoch 235/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3245 - categorical_accuracy: 0.8519
# Epoch 236/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3236 - categorical_accuracy: 0.8519
# Epoch 237/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3469 - categorical_accuracy: 0.8796
# Epoch 238/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3096 - categorical_accuracy: 0.8611
# Epoch 239/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3005 - categorical_accuracy: 0.8611
# Epoch 240/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2937 - categorical_accuracy: 0.8796
# Epoch 241/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5250 - categorical_accuracy: 0.7500
# Epoch 242/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3474 - categorical_accuracy: 0.8241
# Epoch 243/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.4424 - categorical_accuracy: 0.8056
# Epoch 244/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3841 - categorical_accuracy: 0.8333
# Epoch 245/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2925 - categorical_accuracy: 0.8611
# Epoch 246/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3083 - categorical_accuracy: 0.8796
# Epoch 247/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2897 - categorical_accuracy: 0.8704
# Epoch 248/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.3152 - categorical_accuracy: 0.8333
# Epoch 249/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3694 - categorical_accuracy: 0.8148
# Epoch 250/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3214 - categorical_accuracy: 0.8611
# Epoch 251/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3409 - categorical_accuracy: 0.8241
# Epoch 252/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3187 - categorical_accuracy: 0.8241
# Epoch 253/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2760 - categorical_accuracy: 0.8704
# Epoch 254/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3068 - categorical_accuracy: 0.8426
# Epoch 255/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2918 - categorical_accuracy: 0.8796
# Epoch 256/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2992 - categorical_accuracy: 0.8611
# Epoch 257/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3156 - categorical_accuracy: 0.8611
# Epoch 258/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2654 - categorical_accuracy: 0.8704
# Epoch 259/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2617 - categorical_accuracy: 0.8889
# Epoch 260/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3466 - categorical_accuracy: 0.8333
# Epoch 261/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3282 - categorical_accuracy: 0.8333
# Epoch 262/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3431 - categorical_accuracy: 0.7870
# Epoch 263/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3529 - categorical_accuracy: 0.8056
# Epoch 264/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2823 - categorical_accuracy: 0.8704
# Epoch 265/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3709 - categorical_accuracy: 0.8333
# Epoch 266/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5173 - categorical_accuracy: 0.7407
# Epoch 267/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3990 - categorical_accuracy: 0.8056
# Epoch 268/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3971 - categorical_accuracy: 0.8333
# Epoch 269/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3399 - categorical_accuracy: 0.8148
# Epoch 270/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3226 - categorical_accuracy: 0.8426
# Epoch 271/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3770 - categorical_accuracy: 0.8148
# Epoch 272/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3770 - categorical_accuracy: 0.8519
# Epoch 273/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3293 - categorical_accuracy: 0.8333
# Epoch 274/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3002 - categorical_accuracy: 0.8611
# Epoch 275/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2915 - categorical_accuracy: 0.8611
# Epoch 276/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3276 - categorical_accuracy: 0.8426
# Epoch 277/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2853 - categorical_accuracy: 0.8704
# Epoch 278/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2715 - categorical_accuracy: 0.8796
# Epoch 279/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3166 - categorical_accuracy: 0.8241
# Epoch 280/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2917 - categorical_accuracy: 0.8796
# Epoch 281/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2532 - categorical_accuracy: 0.8889
# Epoch 282/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2876 - categorical_accuracy: 0.8611
# Epoch 283/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2576 - categorical_accuracy: 0.8889
# Epoch 284/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2777 - categorical_accuracy: 0.8796
# Epoch 285/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2694 - categorical_accuracy: 0.8704
# Epoch 286/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2788 - categorical_accuracy: 0.8241
# Epoch 287/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3109 - categorical_accuracy: 0.8148
# Epoch 288/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3025 - categorical_accuracy: 0.8426
# Epoch 289/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.8993 - categorical_accuracy: 0.6574
# Epoch 290/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.7026 - categorical_accuracy: 0.6759
# Epoch 291/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.9820 - categorical_accuracy: 0.6019
# Epoch 292/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.9633 - categorical_accuracy: 0.5833
# Epoch 293/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.7360 - categorical_accuracy: 0.6389
# Epoch 294/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.9191 - categorical_accuracy: 0.5648
# Epoch 295/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.6458 - categorical_accuracy: 0.6481
# Epoch 296/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4338 - categorical_accuracy: 0.7963
# Epoch 297/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4811 - categorical_accuracy: 0.7685
# Epoch 298/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4433 - categorical_accuracy: 0.8148
# Epoch 299/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3810 - categorical_accuracy: 0.8981
# Epoch 300/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3502 - categorical_accuracy: 0.9074
# Epoch 301/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3276 - categorical_accuracy: 0.8889
# Epoch 302/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3113 - categorical_accuracy: 0.8981
# Epoch 303/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2937 - categorical_accuracy: 0.9167
# Epoch 304/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2862 - categorical_accuracy: 0.9167
# Epoch 305/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2699 - categorical_accuracy: 0.8796
# Epoch 306/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2835 - categorical_accuracy: 0.8889
# Epoch 307/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.3435 - categorical_accuracy: 0.8426
# Epoch 308/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.3389 - categorical_accuracy: 0.8426
# Epoch 309/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.3921 - categorical_accuracy: 0.7963
# Epoch 310/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.3329 - categorical_accuracy: 0.8333
# Epoch 311/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.2706 - categorical_accuracy: 0.8796
# Epoch 312/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3057 - categorical_accuracy: 0.8519
# Epoch 313/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2784 - categorical_accuracy: 0.8611
# Epoch 314/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2595 - categorical_accuracy: 0.9167
# Epoch 315/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2563 - categorical_accuracy: 0.8981
# Epoch 316/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2477 - categorical_accuracy: 0.8981
# Epoch 317/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2461 - categorical_accuracy: 0.8889
# Epoch 318/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2540 - categorical_accuracy: 0.8889
# Epoch 319/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2604 - categorical_accuracy: 0.8889
# Epoch 320/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3191 - categorical_accuracy: 0.8611
# Epoch 321/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3085 - categorical_accuracy: 0.8519
# Epoch 322/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4096 - categorical_accuracy: 0.8148
# Epoch 323/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5743 - categorical_accuracy: 0.7407
# Epoch 324/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.6099 - categorical_accuracy: 0.7315
# Epoch 325/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.5095 - categorical_accuracy: 0.7130
# Epoch 326/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.5533 - categorical_accuracy: 0.7130
# Epoch 327/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.4332 - categorical_accuracy: 0.8148
# Epoch 328/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3641 - categorical_accuracy: 0.8056
# Epoch 329/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2885 - categorical_accuracy: 0.9167
# Epoch 330/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.3237 - categorical_accuracy: 0.8426
# Epoch 331/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.3426 - categorical_accuracy: 0.8426
# Epoch 332/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.2718 - categorical_accuracy: 0.9074
# Epoch 333/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.2686 - categorical_accuracy: 0.9167
# Epoch 334/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 0.2470 - categorical_accuracy: 0.8889
# Epoch 335/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.2456 - categorical_accuracy: 0.8796
# Epoch 336/1000
# 4/4 [==============================] - 0s 79ms/step - loss: 0.2368 - categorical_accuracy: 0.8796
# Epoch 337/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.2317 - categorical_accuracy: 0.9167
# Epoch 338/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.2410 - categorical_accuracy: 0.8981
# Epoch 339/1000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.2297 - categorical_accuracy: 0.9074
# Epoch 340/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.2542 - categorical_accuracy: 0.8796
# Epoch 341/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.3960 - categorical_accuracy: 0.7963
# Epoch 342/1000
# 4/4 [==============================] - 0s 77ms/step - loss: 0.6156 - categorical_accuracy: 0.6852
# Epoch 343/1000
# 4/4 [==============================] - 0s 95ms/step - loss: 0.4896 - categorical_accuracy: 0.7778
# Epoch 344/1000
# 4/4 [==============================] - 0s 87ms/step - loss: 0.4149 - categorical_accuracy: 0.8519
# Epoch 345/1000
# 4/4 [==============================] - 0s 72ms/step - loss: 0.3681 - categorical_accuracy: 0.8148
# Epoch 346/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.3071 - categorical_accuracy: 0.8333
# Epoch 347/1000
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2843 - categorical_accuracy: 0.8704
# Epoch 348/1000
# 4/4 [==============================] - 0s 83ms/step - loss: 0.2430 - categorical_accuracy: 0.9259
# Epoch 349/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.2577 - categorical_accuracy: 0.9259
# Epoch 350/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.2685 - categorical_accuracy: 0.8796
# Epoch 351/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2808 - categorical_accuracy: 0.8796
# Epoch 352/1000
# 4/4 [==============================] - 0s 93ms/step - loss: 0.3511 - categorical_accuracy: 0.8426
# Epoch 353/1000
# 4/4 [==============================] - 0s 78ms/step - loss: 0.2942 - categorical_accuracy: 0.8519
# Epoch 354/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2974 - categorical_accuracy: 0.8519
# Epoch 355/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.2470 - categorical_accuracy: 0.8796
# Epoch 356/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2220 - categorical_accuracy: 0.9074
# Epoch 357/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2161 - categorical_accuracy: 0.9259
# Epoch 358/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2221 - categorical_accuracy: 0.8889
# Epoch 359/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2143 - categorical_accuracy: 0.8981
# Epoch 360/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.2136 - categorical_accuracy: 0.9167
# Epoch 361/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2248 - categorical_accuracy: 0.8796
# Epoch 362/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.2112 - categorical_accuracy: 0.9074
# Epoch 363/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.2237 - categorical_accuracy: 0.8704
# Epoch 364/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2196 - categorical_accuracy: 0.9074
# Epoch 365/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2180 - categorical_accuracy: 0.8981
# Epoch 366/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2595 - categorical_accuracy: 0.8981
# Epoch 367/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4031 - categorical_accuracy: 0.7963
# Epoch 368/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3826 - categorical_accuracy: 0.7963
# Epoch 369/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2512 - categorical_accuracy: 0.8611
# Epoch 370/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2770 - categorical_accuracy: 0.8519
# Epoch 371/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2990 - categorical_accuracy: 0.8889
# Epoch 372/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3125 - categorical_accuracy: 0.8056
# Epoch 373/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2973 - categorical_accuracy: 0.8611
# Epoch 374/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2185 - categorical_accuracy: 0.9167
# Epoch 375/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2154 - categorical_accuracy: 0.8889
# Epoch 376/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1871 - categorical_accuracy: 0.9074
# Epoch 377/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.1844 - categorical_accuracy: 0.9074
# Epoch 378/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1912 - categorical_accuracy: 0.9352
# Epoch 379/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.1849 - categorical_accuracy: 0.9074
# Epoch 380/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.2449 - categorical_accuracy: 0.8611
# Epoch 381/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.1945 - categorical_accuracy: 0.9074
# Epoch 382/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 0.1758 - categorical_accuracy: 0.9259
# Epoch 383/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1815 - categorical_accuracy: 0.9074
# Epoch 384/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.1839 - categorical_accuracy: 0.9259
# Epoch 385/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1961 - categorical_accuracy: 0.8981
# Epoch 386/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.4712 - categorical_accuracy: 0.9352
# Epoch 387/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 2.5385 - categorical_accuracy: 0.5370
# Epoch 388/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 3.5369 - categorical_accuracy: 0.3056
# Epoch 389/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 2.7423 - categorical_accuracy: 0.3611
# Epoch 390/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 2.1698 - categorical_accuracy: 0.5370
# Epoch 391/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 1.0330 - categorical_accuracy: 0.4722
# Epoch 392/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 1.0972 - categorical_accuracy: 0.5741
# Epoch 393/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 1.0848 - categorical_accuracy: 0.5278
# Epoch 394/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 1.0117 - categorical_accuracy: 0.4074
# Epoch 395/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.9271 - categorical_accuracy: 0.5556
# Epoch 396/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 0.7874 - categorical_accuracy: 0.6296
# Epoch 397/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.8140 - categorical_accuracy: 0.6296
# Epoch 398/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.6631 - categorical_accuracy: 0.7037
# Epoch 399/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6271 - categorical_accuracy: 0.6574
# Epoch 400/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.6566 - categorical_accuracy: 0.6759
# Epoch 401/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.6105 - categorical_accuracy: 0.6574
# Epoch 402/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.6018 - categorical_accuracy: 0.6852
# Epoch 403/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.6072 - categorical_accuracy: 0.7037
# Epoch 404/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.5673 - categorical_accuracy: 0.8333
# Epoch 405/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.5333 - categorical_accuracy: 0.8889
# Epoch 406/1000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.5594 - categorical_accuracy: 0.6667
# Epoch 407/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.5192 - categorical_accuracy: 0.8426
# Epoch 408/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.5357 - categorical_accuracy: 0.8241
# Epoch 409/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.4817 - categorical_accuracy: 0.8241
# Epoch 410/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5307 - categorical_accuracy: 0.7037
# Epoch 411/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.4712 - categorical_accuracy: 0.8704
# Epoch 412/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4633 - categorical_accuracy: 0.8611
# Epoch 413/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4528 - categorical_accuracy: 0.8148
# Epoch 414/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.4262 - categorical_accuracy: 0.8519
# Epoch 415/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 0.4384 - categorical_accuracy: 0.8426
# Epoch 416/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.4319 - categorical_accuracy: 0.8056
# Epoch 417/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.4731 - categorical_accuracy: 0.7685
# Epoch 418/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.5932 - categorical_accuracy: 0.6574
# Epoch 419/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 0.5672 - categorical_accuracy: 0.7037
# Epoch 420/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 0.6110 - categorical_accuracy: 0.6574
# Epoch 421/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.4971 - categorical_accuracy: 0.8148
# Epoch 422/1000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.4283 - categorical_accuracy: 0.8426
# Epoch 423/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 0.3463 - categorical_accuracy: 0.9259
# Epoch 424/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.3247 - categorical_accuracy: 0.9259
# Epoch 425/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.3354 - categorical_accuracy: 0.8981
# Epoch 426/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 0.3194 - categorical_accuracy: 0.8981
# Epoch 427/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3022 - categorical_accuracy: 0.9074
# Epoch 428/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.3348 - categorical_accuracy: 0.8889
# Epoch 429/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.4365 - categorical_accuracy: 0.8148
# Epoch 430/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3697 - categorical_accuracy: 0.8148
# Epoch 431/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.3076 - categorical_accuracy: 0.8426
# Epoch 432/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.3118 - categorical_accuracy: 0.8426
# Epoch 433/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2497 - categorical_accuracy: 0.9688
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-4b82b32f827f> in <module>
#       1 # epochs, callback
# ----> 2 model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                442112
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 446,467
# Trainable params: 446,467
# Non-trainable params: 0
# _________________________________________________________________

# %%
def accuracy(X, y):
    res = model.predict(X)
    accuracy = (np.argmax(res, axis=1) == np.argmax(y, axis=1)).sum()/len(res)
    print(actions[np.argmax(res, axis=1)])
    print(actions[np.argmax(y, axis=1)])
    return accuracy

# %%
accuracy(X_train, y_train)
# Out:
# ['meeting' 'meeting' 'meeting' 'end' 'meeting' 'thank' 'meeting' 'end'
#  'thank' 'thank' 'thank' 'thank' 'end' 'meeting' 'thank' 'end' 'thank'
#  'thank' 'end' 'thank' 'thank' 'meeting' 'thank' 'end' 'end' 'thank'
#  'thank' 'thank' 'thank' 'thank' 'meeting' 'thank' 'end' 'thank' 'end'
#  'meeting' 'end' 'meeting' 'end' 'end' 'end' 'thank' 'thank' 'thank'
#  'thank' 'end' 'meeting' 'thank' 'thank' 'end' 'end' 'thank' 'end' 'end'
#  'thank' 'thank' 'thank' 'end' 'end' 'thank' 'end' 'thank' 'meeting'
#  'thank' 'thank' 'thank' 'thank' 'thank' 'end' 'end' 'meeting' 'thank'
#  'end' 'meeting' 'end' 'meeting' 'meeting' 'end' 'meeting' 'thank' 'thank'
#  'end' 'thank' 'thank' 'thank' 'meeting' 'end' 'meeting' 'meeting'
#  'meeting' 'thank' 'thank' 'end' 'end' 'thank' 'end' 'end' 'thank' 'end'
#  'end' 'end' 'meeting' 'end' 'end' 'meeting' 'end' 'thank' 'end']
# ['meeting' 'meeting' 'meeting' 'end' 'meeting' 'thank' 'meeting' 'end'
#  'thank' 'thank' 'thank' 'meeting' 'end' 'meeting' 'thank' 'end' 'thank'
#  'thank' 'end' 'thank' 'meeting' 'meeting' 'thank' 'end' 'thank' 'thank'
#  'meeting' 'thank' 'thank' 'thank' 'meeting' 'thank' 'end' 'meeting' 'end'
#  'meeting' 'end' 'meeting' 'end' 'end' 'thank' 'thank' 'meeting' 'meeting'
#  'thank' 'end' 'meeting' 'thank' 'thank' 'end' 'end' 'meeting' 'end' 'end'
#  'thank' 'thank' 'meeting' 'end' 'thank' 'thank' 'end' 'thank' 'meeting'
#  'thank' 'meeting' 'thank' 'thank' 'thank' 'end' 'end' 'meeting' 'thank'
#  'end' 'meeting' 'end' 'meeting' 'meeting' 'end' 'meeting' 'thank' 'thank'
#  'end' 'meeting' 'thank' 'thank' 'meeting' 'end' 'meeting' 'meeting'
#  'meeting' 'thank' 'meeting' 'end' 'end' 'thank' 'end' 'end' 'thank' 'end'
#  'thank' 'end' 'meeting' 'end' 'end' 'meeting' 'end' 'thank' 'end']
# 0.8611111111111112

# %%
accuracy(X_test, y_test)
# Out:
# ['end' 'end' 'meeting' 'end' 'end' 'end' 'meeting' 'thank' 'thank'
#  'meeting' 'end' 'thank']
# ['end' 'thank' 'meeting' 'end' 'end' 'end' 'meeting' 'meeting' 'meeting'
#  'meeting' 'end' 'meeting']
# 0.6666666666666666

# %%
res = model.predict(X[17].reshape(-1, 30, 1662))
actions[np.argmax(res, axis=1)]

# %%
actions[np.argmax(y[17])]

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Make detections
        results = mediapipe_detection(frame, holistic)
        # Draw landmarks
        draw_styled_landmarks(frame, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            frame = prob_viz(res, actions, frame, colors)
            
        cv2.rectangle(frame, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(frame, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', frame)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# meeting
# end
# end
# end
# end
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# meeting
# end
# end
# end
# end
# end
# end
# end
# end
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# meeting
# end
# end
# end
# end
# end
# thank
# thank
# thank
# meeting
# meeting
# thank
# meeting
# thank
# thank
# thank
# meeting
# thank
# meeting
# meeting
# meeting
# thank
# thank
# thank
# thank
# thank
# thank
# meeting
# end
# end
# end
# end
# end
# end
# end
# end
# thank
# thank
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# thank
# thank
# meeting
# meeting
# end
# end
# end
# end
# end
# thank
# thank
# thank
# end
# end
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# meeting
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# thank
# meeting
# meeting
# meeting
# end
# end
# end
# end
# end
# thank
# thank
# thank
# end
# end
# end
# end
# thank
# end
# thank
# thank
# thank
# thank
# thank
# meeting
# thank
# meeting
# meeting
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# thank
# thank
# thank
# thank
# end
# end
# end
# thank
# end
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# meeting
# end
# end
# end
# end
# end
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# meeting
# meeting
# meeting
# meeting
# thank
# thank
# thank
# thank
# meeting
# thank
# meeting
# meeting
# meeting
# meeting
# thank
# meeting
# thank
# meeting
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# end
# end
# end
# end
# thank
# meeting
# meeting
# meeting
# meeting
# thank
# thank
# meeting
# thank
# thank
# meeting
# meeting
# meeting
# meeting
# thank
# thank
# end
# end
# meeting
# thank
# meeting
# meeting
# meeting
# meeting
# thank
# meeting
# meeting
# thank
# end
# end
# end
# end
# end
# end
# meeting
# meeting
# meeting
# thank
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# thank
# meeting
# meeting
# meeting
# thank
# meeting
# end
# end
# end
# end
# end
# meeting
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# meeting
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# thank
# thank
# thank
# thank
# thank
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# thank
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
# thank
# meeting
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# meeting
# meeting
# thank
# meeting
# meeting
# end
# end
# end
# end
# end
# end
# end
# end
# end
# thank
# end
# end
# end
# end
# meeting
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# thank
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# meeting
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# meeting
# meeting
# end
# end
# thank
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# thank
# meeting
# meeting
# meeting
# meeting
# meeting
# meeting
